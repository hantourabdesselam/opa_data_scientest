# %%
from binance.client import Client
from datetime import datetime, timedelta
import pandas as pd
from pymongo import MongoClient


# Initialize the MongoDB client
mongo_client = MongoClient("mongodb://localhost:27017/")  # Remplacez par votre URL MongoDB si nécessaire
db = mongo_client['crypto_data']  # Remplacez par votre nom de base de données
collection = db['historical_prices']  # Remplacez par votre nom de collection

df = pd.read_csv('../out/symbols_prices.csv', sep=';')



# Convert the DataFrame to a list of dictionaries
data_dict = df.to_dict("records")
collection.insert_many(data_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hm/vlzg6l1j13n6blrhmm6gq9b00000gp/T/ipykernel_8867/3987415848.py in <module>
#      16 # Convert the DataFrame to a list of dictionaries
#      17 data_dict = df.to_dict("records")
# ---> 18 collection.insert_many(data_dict)
#      19
#
# /opt/anaconda3/lib/python3.9/site-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     105                 with _TimeoutContext(timeout):
#     106                     return func(self, *args, **kwargs)
# --> 107         return func(self, *args, **kwargs)
#     108
#     109     return cast(F, csot_wrapper)
#
# /opt/anaconda3/lib/python3.9/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
# ...
